# %% [markdown]
# Function Example

# %%
def rescale_vector(vec):
  
  """
  Rescales a numeric vector to have a max of 1 and min of 0
  
  Parameter
  ---------
  vec : num
    A list, numpy array, or pandas Series of numeric data.

  Returns
  -------
  array 
    A numpy array containing the rescaled values.
  """
  
  min_vec = min(vec)
  max_vec = max(vec)
  
  rescaled_vec = (vec - min_vec)/(max_vec - min_vec)
  
  return rescaled_vec

# %%
help(rescale_vector)

# %% [markdown]
# Name Masking

# %%
import palmerpenguins
from palmerpenguins import *
from plotnine import *

# %%
from plotnine import ggplot, aes, geom_point
from palmerpenguins import load_penguins

penguins = load_penguins()

def penguin_scatterplot(data, species, island):
    subset = data[(data['species'] == species) & (data['island'] == island)]
    plot = (
        ggplot(subset, aes(x='bill_length_mm', y='bill_depth_mm')) +
        geom_point()
    )
    return plot

scatter_plot = penguin_scatterplot(penguins, 'Adelie', 'Biscoe')
print(scatter_plot)
# Out:
# <positron-console-cell-13>:15: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /opt/anaconda3/lib/python3.12/pprint.py:632: FutureWarning: Using repr(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().

# %% [markdown]
# Interation

# %%
def sing_verse(num):
  song = str(num) + " bottles of beer on the wall \n" + str(num) + " bottles of beer \n" + " take one down, pass it around, \n" + str(num-1) + " bottles of beer on the wall \n"
  
  return song

# %%
song = ""

for i in range(100,97,-1):
  song = song + sing_verse(i)
  
print(song)
# Out:
# 100 bottles of beer on the wall
# 100 bottles of beer
#  take one down, pass it around,
# 99 bottles of beer on the wall
# 99 bottles of beer on the wall
# 99 bottles of beer
#  take one down, pass it around,
# 98 bottles of beer on the wall
# 98 bottles of beer on the wall
# 98 bottles of beer
#  take one down, pass it around,
# 97 bottles of beer on the wall
#
# 100 bottles of beer on the wall
# 100 bottles of beer
#  take one down, pass it around,
# 99 bottles of beer on the wall
# 99 bottles of beer on the wall
# 99 bottles of beer
#  take one down, pass it around,
# 98 bottles of beer on the wall
# 98 bottles of beer on the wall
# 98 bottles of beer
#  take one down, pass it around,
# 97 bottles of beer on the wall

# %% [markdown]
# To modify to the code above to make it print out a list and make the lyrics as an element of that list

# %%
song = []

for i in range(100,97,-1):
  song.append(sing_verse(i))
  
print(song)
# Out:
# ['100 bottles of beer on the wall \n100 bottles of beer \n take one down, pass it around, \n99 bottles of beer on the wall \n', '99 bottles of beer on the wall \n99 bottles of beer \n take one down, pass it around, \n98 bottles of beer on the wall \n', '98 bottles of beer on the wall \n98 bottles of beer \n take one down, pass it around, \n97 bottles of beer on the wall \n']
# ['100 bottles of beer on the wall \n100 bottles of beer \n take one down, pass it around, \n99 bottles of beer on the wall \n', '99 bottles of beer on the wall \n99 bottles of beer \n take one down, pass it around, \n98 bottles of beer on the wall \n', '98 bottles of beer on the wall \n98 bottles of beer \n take one down, pass it around, \n97 bottles of beer on the wall \n']

# %%
import numpy as np
def sqrt_pos_unvec(num):
    if num > 0:
        return np.sqrt(num)
    else:
        return(num)

new_vec = []

for val in a_vec:
    new_vec.append(sqrt_pos_unvec(val))

print(new_vec)

# %%
def sqrt_pos_vec(x):
    if is_pos > 0
    x(is_pos) = np.sqrt(x[is_pos])
    return x

print(a_vec)
sqrt_pos_vec(a_vec)
