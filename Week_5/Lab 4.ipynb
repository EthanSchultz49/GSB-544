# %%
import pandas as pd

# %%
import requests
response = requests.get("https://worldpopulationreview.com/state-rankings/starbucks-stores-by-state#google_vignette")

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# %%
table = soup.find("table", class_="wpr-table")
table
# Out:
# <table class="wpr-table"><thead class="table-head bg-wpr-table_header_bg relative z-40 px-0 py-0 text-xs uppercase tracking-wider"><tr><th class="datatable-th bg-wpr-table_header_bg text-wpr-table_header border-wpr-table_border sticky top-0 border-b bg-clip-padding px-3 py-2 text-left align-bottom leading-4 md:px-4 pin left-0 z-50 border-l-0"><div class="flex flex-col items-stretch justify-start"><div class="flex flex-row items-center cursor-pointer select-none">State</div></div></th><th class="datatable-th bg-wpr-table_header_bg text-wpr-table_header border-wpr-table_border sticky top-0 border-b bg-clip-padding px-3 py-2 text-left align-bottom leading-4 md:px-4 z-40"><div class="flex flex-col items-stretch justify-start"><div class="flex flex-row items-center cursor-pointer select-none">Starbucks Stores 2023<svg class="icon icon-tabler icon-tabler-chevron-down" fill="none" height="14" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M0 0h24v24H0z" fill="none" stroke="none"></path><polyline points="6 9 12 15 18 9"></polyline></svg></div></div></th><th class="datatable-th bg-wpr-table_header_bg text-wpr-table_header border-wpr-table_border sticky top-0 border-b bg-clip-padding px-3 py-2 text-left align-bottom leading-4 md:px-4 z-40"><div class="flex flex-col items-stretch justify-start"><div class="flex flex-row items-center cursor-pointer select-none">Starbucks Stores 2021</div></div></th><th class="datatable-th bg-wpr-table_header_bg text-wpr-table_header border-wpr-table_border sticky top-0 border-b bg-clip-padding px-3 py-2 text-left align-bottom leading-4 md:px-4 z-40"><div class="flex flex-col items-stretch justify-start"><div class="flex flex-row items-center cursor-pointer select-none">Starbucks Stores 2024</div></div></th></tr></thead><tbody class="relative z-10 text-sm"><tr class="table-row" data-state="false"><th class="text-wpr-table_header sticky left-0 z-50 bg-clip-padding py-1.5 pl-3 text-left align-middle text-sm md:px-4"><a class="text-wpr-link" href="/states/california" to="/states/california">California</a></th><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">3,080</td><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">2,959</td><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">3,117</td></tr><tr class="table-row" data-state="false"><th class="text-wpr-table_header sticky left-0 z-50 bg-clip-padding py-1.5 pl-3 text-left align-middle text-sm md:px-4"><a class="text-wpr-link" href="/states/texas" to="/states/texas">Texas</a></th><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">1,346</td><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">1,215</td><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">1,409</td></tr><tr class="table-row" data-state="false"><th class="text-wpr-table_header sticky left-0 z-50 bg-clip-padding py-1.5 pl-3 text-left align-middle text-sm md:px-4"><a class="text-wpr-link" href="/states/florida" to="/states/florida">Florida</a></th><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">844</td><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">786</td><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">892</td></tr><tr class="table-row" data-state="false"><th class="text-wpr-table_header sticky left-0 z-50 bg-clip-padding py-1.5 pl-3 text-left align-middle text-sm md:px-4"><a class="text-wpr-link" href="/states/washington" to="/states/washington">Washington</a></th><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">741</td><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">739</td><td class="text-wpr-table_text z-40 px-3 py-1.5 text-sm md:px-4">736</td></tr><tr class="table-row" data-state="false"><th class="text-wpr-table_header sticky left-0 z-50 bg-clip-padding py-1.5 pl-3 text-left align-middle text-sm md:px-4"><a class="tex ...

# %%
#1
# initialize an empty list
rows = []

# iterate over all rows in the faculty table
for coffee in table.find_all("tr")[1:]:
    state = coffee.find_all("th")
    cells = coffee.find_all("td")

    # get the state names
    state_tag = state[0].find("a") or state[0]
    states = state_tag.get_text(strip = True)

    # get the different data for years
    year2023_tag = cells[0].find("td") or cells[0]
    year2023 = year2023_tag.get_text(strip = True)

    year2024_tag = cells[2].find("td") or cells[2]
    year2024 = year2024_tag.get_text(strip = True)

    year2021_tag = cells[1].find("td") or cells[1]
    year2021 = year2021_tag.get_text(strip = True)

    # Append this data.
    rows.append({
        "States": states, 
        "Starbucks 2021": year2021,
        "Starbucks 2023": year2023,
        "Starbucks 2024": year2024
       
    })

# %%
starbucks = pd.DataFrame(rows)
starbucks
# Out:
#                   States Starbucks 2021 Starbucks 2023 Starbucks 2024
# 0             California          2,959          3,080          3,117
# 1                  Texas          1,215          1,346          1,409
# 2                Florida            786            844            892
# 3             Washington            739            741            736
# 4               New York            643            692            715
# 5               Illinois            621            677            685
# 6                Arizona            535            548            579
# 7               Colorado            497            495            506
# 8                   Ohio            446            491            499
# 9               Virginia            456            489            510
# 10                Oregon            345            359
# 11          Pennsylvania            406            357
# 12        North Carolina            422            338
# 13               Georgia            379            326
# 14              Michigan            310            283
# 15         Massachusetts            279            273
# 16            New Jersey            293            261
# 17              Maryland            274            257
# 18                Nevada            269            253
# 19               Indiana            265            221
# 20              Missouri            208            188
# 21             Minnesota            212            184
# 22             Tennessee            237            180
# 23              Kentucky            131            166
# 24             Wisconsin            176            145
# 25        South Carolina            207            131
# 26           Connecticut            125            123
# 27                  Utah            126            101
# 28                Hawaii            105             99
# 29                Kansas            120             94
# 30  District of Columbia                            91
# 31                  Iowa            142             89
# 32               Alabama             99             85
# 33             Louisiana             10             84
# 34              Oklahoma             94             79
# 35            New Mexico             92             76
# 36                 Idaho             78             67
# 37              Nebraska             87             58
# 38              Arkansas             66             55
# 39                Alaska             49             49
# 40           Mississippi             36             32
# 41               Montana             45             32
# 42                 Maine             31             30
# 43         New Hampshire             35             29
# 44          Rhode Island             26             27
# 45              Delaware             39             25
# 46          South Dakota             52             25
# 47         West Virginia             64             25
# 48               Wyoming             26             23
# 49          North Dakota             20             13
# 50               Vermont             35              8

# %%
response = requests.get("https://worldpopulationreview.com/state-rankings/dunkin-donuts-by-state")
soup = BeautifulSoup(response.content, "html.parser")
table1 = soup.find("table", class_="wpr-table")

# %%
#1
# initialize an empty list
rows1 = []

# iterate over all rows in the faculty table
for coffee in table1.find_all("tr")[1:]:
    state = coffee.find_all("th")
    cells = coffee.find_all("td")

    # get the state names
    state_tag = state[0].find("a") or state[0]
    states = state_tag.get_text(strip = True)

    # get the different data for years
    year2024_tag = cells[0].find("td") or cells[0]
    year2024 = year2024_tag.get_text(strip = True)

    year2023_tag = cells[1].find("td") or cells[1]
    year2023 = year2023_tag.get_text(strip = True)

    # Append this data.
    rows1.append({
        "States": states, 
        "Dunkin-Donuts 2023": year2023,
        "Dunkin-Donuts 2024": year2024,
       
    })

# %%
dunkin = pd.DataFrame(rows1)
dunkin
# Out:
#                   States Dunkin-Donuts 2023 Dunkin-Donuts 2024
# 0               New York              1,414              1,431
# 1          Massachusetts              1,068              1,042
# 2                Florida                883                909
# 3             New Jersey                866                872
# 4               Illinois                692                711
# 5           Pennsylvania                629                650
# 6            Connecticut                480                476
# 7               Maryland                303                311
# 8                Georgia                265                287
# 9                   Ohio                245                261
# 10              Virginia                230                244
# 11                 Texas                196                226
# 12        North Carolina                206                224
# 13         New Hampshire                218                216
# 14                 Maine                159                164
# 15          Rhode Island                160                159
# 16            California                134                143
# 17             Tennessee                123                137
# 18               Indiana                104                117
# 19        South Carolina                103                116
# 20              Michigan                105                112
# 21               Arizona                102                110
# 22             Wisconsin                 83                100
# 23               Alabama                 59                 69
# 24              Delaware                 66                 67
# 25              Missouri                 50                 54
# 26              Kentucky                 41                 50
# 27               Vermont                 49                 50
# 28              Colorado                 43                 48
# 29                Nevada                 38                 42
# 30             Minnesota                 34                 38
# 31                  Iowa                 34                 36
# 32         West Virginia                 27                 31
# 33                Kansas                 28                 26
# 34              Nebraska                 23                 24
# 35              Oklahoma                 18                 23
# 36  District of Columbia                                    19
# 37            New Mexico                 19                 19
# 38             Louisiana                 16                 15
# 39              Arkansas                  9                 14
# 40           Mississippi                 12                 14
# 41                Hawaii                  6                  6
# 42                  Utah                  1                  2
# 43               Wyoming                  1                  1
# 44                Alaska                  0                  0
# 45                 Idaho                  0                  0
# 46               Montana                  0                  0
# 47          North Dakota                  0                  0
# 48                Oregon                  0                  0
# 49          South Dakota                  0                  0
# 50            Washington                 19                  0

# %%
merged = starbucks.merge(dunkin, on = ["States"], 
how = "outer")
merged.head()
long = merged.melt(id_vars=["States"], value_vars=["Starbucks 2021", "Starbucks 2023", "Starbucks 2024", "Dunkin-Donuts 2023", "Dunkin-Donuts 2024"], var_name="Year_Brand", value_name="stores")
# Split the 'Year_Brand' column into 'Year' and 'Brand'
long[['Brand', 'Year']] = long['Year_Brand'].str.split(' ', expand=True)
# Drop the 'Year_Brand' column if no longer needed
long = long.drop(columns=['Year_Brand'])
# Out:
#             States stores          Brand  Year
# 0          Alabama     99      Starbucks  2021
# 1           Alaska     49      Starbucks  2021
# 2          Arizona    535      Starbucks  2021
# 3         Arkansas     66      Starbucks  2021
# 4       California  2,959      Starbucks  2021
# ..             ...    ...            ...   ...
# 250       Virginia    244  Dunkin-Donuts  2024
# 251     Washington      0  Dunkin-Donuts  2024
# 252  West Virginia     31  Dunkin-Donuts  2024
# 253      Wisconsin    100  Dunkin-Donuts  2024
# 254        Wyoming      1  Dunkin-Donuts  2024
#
# [255 rows x 4 columns]
#             States stores          Brand  Year
# 0          Alabama     99      Starbucks  2021
# 1           Alaska     49      Starbucks  2021
# 2          Arizona    535      Starbucks  2021
# 3         Arkansas     66      Starbucks  2021
# 4       California  2,959      Starbucks  2021
# ..             ...    ...            ...   ...
# 250       Virginia    244  Dunkin-Donuts  2024
# 251     Washington      0  Dunkin-Donuts  2024
# 252  West Virginia     31  Dunkin-Donuts  2024
# 253      Wisconsin    100  Dunkin-Donuts  2024
# 254        Wyoming      1  Dunkin-Donuts  2024
#
# [255 rows x 4 columns]

# %%
response = requests.get("https://simple.wikipedia.org/wiki/List_of_U.S._states_by_population")
soup = BeautifulSoup(response.content, "html.parser")

tables = soup.find_all("table", class_ = "wikitable")

#get first table that we want
table = tables[0]

rows = []

for tr in table.find_all("tr")[1:]:
    cells = tr.find_all("td")

    # get states
    state_tag = cells[2].find("a") or cells[2]
    state = state_tag.get_text(strip = True)

    # get population
    pop_tag = cells[3].find("a") or cells[3]
    population = pop_tag.get_text(strip = True)

    # append data
    rows.append({
        "States" : state,
        "population" : population
    })

# convert to a df
population = pd.DataFrame(rows)
population.head()

withpop = long.merge(population, on = "States", how = "left")
withpop
# Out:
#             States stores          Brand  Year  population
# 0          Alabama     99      Starbucks  2021   5,024,279
# 1           Alaska     49      Starbucks  2021     733,391
# 2          Arizona    535      Starbucks  2021   7,151,502
# 3         Arkansas     66      Starbucks  2021   3,011,524
# 4       California  2,959      Starbucks  2021  39,538,223
# ..             ...    ...            ...   ...         ...
# 250       Virginia    244  Dunkin-Donuts  2024   8,631,393
# 251     Washington      0  Dunkin-Donuts  2024   7,705,281
# 252  West Virginia     31  Dunkin-Donuts  2024   1,793,716
# 253      Wisconsin    100  Dunkin-Donuts  2024   5,893,718
# 254        Wyoming      1  Dunkin-Donuts  2024     576,851
#
# [255 rows x 5 columns]

# %%
withpop["Starbucks Stock Price"] = 97.21
withpop["Dunkin Stock Price"] = 106.48

# %%
withpop.head()
# Out:
#        States stores  ... Starbucks Stock Price Dunkin Stock Price
# 0     Alabama     99  ...                 97.21             106.48
# 1      Alaska     49  ...                 97.21             106.48
# 2     Arizona    535  ...                 97.21             106.48
# 3    Arkansas     66  ...                 97.21             106.48
# 4  California  2,959  ...                 97.21             106.48
#
# [5 rows x 7 columns]

# %%
#6
state_to_region = {
    "Connecticut": "Northeast", "Maine": "Northeast", "Massachusetts": "Northeast", "New Hampshire": "Northeast",
    "New Jersey": "Northeast", "New York": "Northeast", "Pennsylvania": "Northeast", "Rhode Island": "Northeast",
    "Vermont": "Northeast",
    "Illinois": "Midwest", "Indiana": "Midwest", "Iowa": "Midwest", "Kansas": "Midwest", "Michigan": "Midwest",
    "Minnesota": "Midwest", "Missouri": "Midwest", "Nebraska": "Midwest", "North Dakota": "Midwest", 
    "Ohio": "Midwest", "South Dakota": "Midwest", "Wisconsin": "Midwest",
    "Alabama": "South", "Arkansas": "South", "Delaware": "South", "Florida": "South", "Georgia": "South",
    "Kentucky": "South", "Louisiana": "South", "Maryland": "South", "Mississippi": "South", 
    "North Carolina": "South", "Oklahoma": "South", "South Carolina": "South", "Tennessee": "South", 
    "Texas": "South", "Virginia": "South", "West Virginia": "South",
    "Alaska": "West", "Arizona": "West", "California": "West", "Colorado": "West", "Hawaii": "West",
    "Idaho": "West", "Montana": "West", "Nevada": "West", "New Mexico": "West", "Oregon": "West",
    "Utah": "West", "Washington": "West", "Wyoming": "West"
}
withpop['Region'] = withpop['States'].map(state_to_region)
withpop.head()
# Out:
#        States stores  ... Dunkin Stock Price Region
# 0     Alabama     99  ...             106.48  South
# 1      Alaska     49  ...             106.48   West
# 2     Arizona    535  ...             106.48   West
# 3    Arkansas     66  ...             106.48  South
# 4  California  2,959  ...             106.48   West
#
# [5 rows x 8 columns]

# %%
# Automate
import re
def scrape_store_data(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    table = soup.find("table")
    
    company_name = re.search(r'state-rankings/(.+?)-stores', url)
    company_name = company_name.group(1).replace("-", " ").title() if company_name else "Unknown"
    
    rows = []

    for coffee in table.find_all("tr")[1:]:
        state = coffee.find_all("th")
        cells = coffee.find_all("td")

        state_tag = state[0].find("a") or state[0]
        states = state_tag.get_text(strip=True)

        year2023 = cells[0].get_text(strip=True)
        year2021 = cells[1].get_text(strip=True)
        year2024 = cells[2].get_text(strip=True)

        rows.append({
            "States": states,
            f"{company_name} 2021": year2021,
            f"{company_name} 2023": year2023,
            f"{company_name} 2024": year2024
        })

    # Convert to DataFrame
    df = pd.DataFrame(rows)
    
    return df

# Example usage
url = "https://worldpopulationreview.com/state-rankings/walmart-stores-by-state"
df = scrape_store_data(url)
print(df)
# Out:
# ---------------------------------------------------------------------------
#
# IndexError                                Traceback (most recent call last)
#
# Cell In[46], line 39
#
#      37 # Example usage
#
#      38 url = "https://worldpopulationreview.com/state-rankings/walmart-stores-by-state"
#
# ---> 39 df = scrape_store_data(url)
#
#      40 print(df)
#
#
#
# Cell In[46], line 22, in scrape_store_data(url)
#
#      19 states = state_tag.get_text(strip=True)
#
#      21 year2023 = cells[0].get_text(strip=True)
#
# ---> 22 year2021 = cells[1].get_text(strip=True)
#
#      23 year2024 = cells[2].get_text(strip=True)
#
#      25 rows.append({
#
#      26     "States": states,
#
#      27     f"{company_name} 2021": year2021,
#
#      28     f"{company_name} 2023": year2023,
#
#      29     f"{company_name} 2024": year2024
#
#      30 })
#
#
#
# IndexError: list index out of range
